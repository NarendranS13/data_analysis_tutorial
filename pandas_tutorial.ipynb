# %% [markdown]
# # Pandas Tutorial

# %% [markdown]
# Pandas Series

# %%
### G7 Nations. Canada, France, Germany, Italy, Japan, UK and US.
import pandas as pd
import numpy as np

# In millions
g7_pop = pd. Series([35.467, 63.951, 80.940, 60.665, 127.06, 64.511, 318.523])

# %%
g7_pop
# Out:
# 0     35.467
# 1     63.951
# 2     80.940
# 3     60.665
# 4    127.060
# 5     64.511
# 6    318.523
# dtype: float64

# %%
# This access the index of the series.
g7_pop[1]
g7_pop[7]
# Out:
# 318.523

# %%
g7_pop.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %% [markdown]
# But, in contrast to lists, we can change the index

# %%
g7_pop.index = [
    "Canada",
    "France",
    "Germany",
    "Italy",
    "Japan",
    "United Kingdom",
    "United States",
]

# %%
g7_pop
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.060
# United Kingdom     64.511
# United States     318.523
# dtype: float64

# %% [markdown]
# ## Indexing

# %%
g7_pop["Canada"]
# Out:
# 35.467

# %%
g7_pop['Japan']
# Out:
# 127.06

# %% [markdown]
# Numeric position can be used with iloc attribute

# %%
### Find the population of France with iloc
g7_pop.iloc[1]
# Out:
# 63.951

# %%
### Find the population of US with iloc
g7_pop.iloc[-1]
# Out:
# 318.523

# %% [markdown]
# Selecting multiple index at once

# %%
g7_pop[['United Kingdom','United States']]
# Out:
# United Kingdom     64.511
# United States     318.523
# dtype: float64

# %% [markdown]
# Slicing also works, but important in Pandas the upper limit is also included

# %%
g7_pop['Canada':'Italy']
# Out:
# Canada     35.467
# France     63.951
# Germany    80.940
# Italy      60.665
# dtype: float64

# %% [markdown]
# Conditional Selection (Boolean Arrays)

# %%
g7_pop > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# dtype: bool

# %%
g7_pop[g7_pop > 70]
# Out:
# Germany           80.940
# Japan            127.060
# United States    318.523
# dtype: float64

# %%
g7_pop[g7_pop > g7_pop.mean()]
# Out:
# Japan            127.060
# United States    318.523
# dtype: float64

# %%
g7_pop.mean()
# Out:
# 107.30242857142856

# %% [markdown]
# Operations on Series

# %%
g7_pop * 2
# Out:
# Canada             70.934
# France            127.902
# Germany           161.880
# Italy             121.330
# Japan             254.120
# United Kingdom    129.022
# United States     637.046
# dtype: float64

# %% [markdown]
# Logic OR & AND

# %%
g7_pop[(g7_pop > 80) & (g7_pop < 200)]
# Out:
# Germany     80.94
# Japan      127.06
# dtype: float64

# %% [markdown]
# Modifying Series

# %%
g7_pop['Canada'] = 40.5

# %%
g7_pop.iloc[-1] = 500

# %%
g7_pop
# Out:
# Canada             40.500
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.060
# United Kingdom     64.511
# United States     500.000
# dtype: float64

# %%
g7_pop[g7_pop < 70]
# Out:
# Canada            40.500
# France            63.951
# Italy             60.665
# United Kingdom    64.511
# dtype: float64

# %%
g7_pop[g7_pop < 70] = 99.99

# %%
g7_pop
# Out:
# Canada             99.99
# France             99.99
# Germany            80.94
# Italy              99.99
# Japan             127.06
# United Kingdom     99.99
# United States     500.00
# dtype: float64

# %% [markdown]
# Pandas DataFrame

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951,80.94,60.655,127.0671,64.511,318.523],
    'GDP': [1785387, 2833687,3874437,2167744,4602367,2950039,17348075],
    'Surface Area': [9984670, 640679,357114,301336,377930,242495,9525067],
    'HDI': [0.913,0.888,0.916,0.873,0.891,0.907,0.915],
    'Continent': ['America','Europe','Europe','Europe','Asia','Europe','America']
}, columns=['Population', 'GDP', 'Surface Area', 'HDI','Continent'])

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0     35.4670   1785387       9984670  0.913   America
# 1     63.9510   2833687        640679  0.888    Europe
# 2     80.9400   3874437        357114  0.916    Europe
# 3     60.6550   2167744        301336  0.873    Europe
# 4    127.0671   4602367        377930  0.891      Asia
# 5     64.5110   2950039        242495  0.907    Europe
# 6    318.5230  17348075       9525067  0.915   America

# %%
### Providing custom indexes with Dataframe
df.index = [
    "Canada",
    "France",
    "Germany",
    "Italy",
    "Japan",
    "United Kingdom",
    "United States",
]

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada             35.4670   1785387       9984670  0.913   America
# France             63.9510   2833687        640679  0.888    Europe
# Germany            80.9400   3874437        357114  0.916    Europe
# Italy              60.6550   2167744        301336  0.873    Europe
# Japan             127.0671   4602367        377930  0.891      Asia
# United Kingdom     64.5110   2950039        242495  0.907    Europe
# United States     318.5230  17348075       9525067  0.915   America

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.shape
# Out:
# (7, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.index
# Out:
# Index(['Canada', 'France', 'Germany', 'Italy', 'Japan', 'United Kingdom',
#        'United States'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302014  5.080248e+06  3.061327e+06  0.900429
# std     97.250976  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.303000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.003550  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.size
# Out:
# 35

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %% [markdown]
# Indexing, Selection and Slicing an DataFrame

# %%
### Require All Data associated with Canada
df.loc['Canada']
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
### Require Surface area of canada
df.loc['Canada','Surface Area']
# Out:
# 9984670

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df['Population']
# Out:
# Canada             35.4670
# France             63.9510
# Germany            80.9400
# Italy              60.6550
# Japan             127.0671
# United Kingdom     64.5110
# United States     318.5230
# Name: Population, dtype: float64

# %%
df['Population'].to_frame
# Out:
# <bound method Series.to_frame of Canada             35.4670
# France             63.9510
# Germany            80.9400
# Italy              60.6550
# Japan             127.0671
# United Kingdom     64.5110
# United States     318.5230
# Name: Population, dtype: float64>

# %%
### Multiple column selection
df[['Population','HDI']]
# Out:
#                 Population    HDI
# Canada             35.4670  0.913
# France             63.9510  0.888
# Germany            80.9400  0.916
# Italy              60.6550  0.873
# Japan             127.0671  0.891
# United Kingdom     64.5110  0.907
# United States     318.5230  0.915

# %%
# iloc-- To access df via numeric fashion
## Using iloc - the slicing will be similar to pandas meaning 3 will not be considered
df.iloc[1:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.iloc[1:3, [0,3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916

# %%
df.iloc[1:3,1:3]
# Out:
#              GDP  Surface Area
# France   2833687        640679
# Germany  3874437        357114

# %% [markdown]
# Conditional Selection (Boolean Arrays)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada             35.4670   1785387       9984670  0.913   America
# France             63.9510   2833687        640679  0.888    Europe
# Germany            80.9400   3874437        357114  0.916    Europe
# Italy              60.6550   2167744        301336  0.873    Europe
# Japan             127.0671   4602367        377930  0.891      Asia
# United Kingdom     64.5110   2950039        242495  0.907    Europe
# United States     318.5230  17348075       9525067  0.915   America

# %%
df['Population'] > 70
# Out:
# Canada            False
# France            False
# Germany            True
# Italy             False
# Japan              True
# United Kingdom    False
# United States      True
# Name: Population, dtype: bool

# %%
df.loc[df['Population'] > 70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany           80.9400   3874437        357114  0.916    Europe
# Japan            127.0671   4602367        377930  0.891      Asia
# United States    318.5230  17348075       9525067  0.915   America

# %%
df.loc[df['Population']>70, ['Population','GDP']]
# Out:
#                Population       GDP
# Germany           80.9400   3874437
# Japan            127.0671   4602367
# United States    318.5230  17348075

# %% [markdown]
# Dropping Stuff
# # Similar to selection, we can do droppin

# %%
df.drop('Canada')
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France             63.9510   2833687        640679  0.888    Europe
# Germany            80.9400   3874437        357114  0.916    Europe
# Italy              60.6550   2167744        301336  0.873    Europe
# Japan             127.0671   4602367        377930  0.891      Asia
# United Kingdom     64.5110   2950039        242495  0.907    Europe
# United States     318.5230  17348075       9525067  0.915   America

# %%
df.drop(['Canada','Japan'])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.655   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %% [markdown]
# Operations

# %%
df[['Population','GDP']] / 100
# Out:
#                 Population        GDP
# Canada            0.354670   17853.87
# France            0.639510   28336.87
# Germany           0.809400   38744.37
# Italy             0.606550   21677.44
# Japan             1.270671   46023.67
# United Kingdom    0.645110   29500.39
# United States     3.185230  173480.75

# %%
crisis = pd.Series([-1_000_000,-0.3], index=['GDP','HDI'])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[['GDP','HDI']]
# Out:
#                      GDP    HDI
# Canada           1785387  0.913
# France           2833687  0.888
# Germany          3874437  0.916
# Italy            2167744  0.873
# Japan            4602367  0.891
# United Kingdom   2950039  0.907
# United States   17348075  0.915

# %%
df[['GDP','HDI']] + crisis
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %%
### In Pandas all operations will be ends up in new Dataframe
### If you want to track them assign them to another dataframe

# %%
langs = pd.Series(
    ['French','German','Italian'],
    index = ['France','Germany','Italy'],
    name = 'Language'
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df['Language'] = langs

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada             35.4670   1785387       9984670  0.913   America      NaN
# France             63.9510   2833687        640679  0.888    Europe   French
# Germany            80.9400   3874437        357114  0.916    Europe   German
# Italy              60.6550   2167744        301336  0.873    Europe  Italian
# Japan             127.0671   4602367        377930  0.891      Asia      NaN
# United Kingdom     64.5110   2950039        242495  0.907    Europe      NaN
# United States     318.5230  17348075       9525067  0.915   America      NaN

# %% [markdown]
# Replacing values per Column

# %%
df['Language']= 'English'

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada             35.4670   1785387       9984670  0.913   America  English
# France             63.9510   2833687        640679  0.888    Europe  English
# Germany            80.9400   3874437        357114  0.916    Europe  English
# Italy              60.6550   2167744        301336  0.873    Europe  English
# Japan             127.0671   4602367        377930  0.891      Asia  English
# United Kingdom     64.5110   2950039        242495  0.907    Europe  English
# United States     318.5230  17348075       9525067  0.915   America  English

# %% [markdown]
# Renaming Columns

# %%
df.rename(
    columns={
        'HDI':'Human Development Index',
        'Anual Popcorn Consumption':'APC'
    }, index = {
        'United States':'USA',
        'United Kingdom': 'UK',
        'Argentina':'AR'
    }
)
# Out:
#          Population       GDP  Surface Area  Human Development Index  \
# Canada      35.4670   1785387       9984670                    0.913
# France      63.9510   2833687        640679                    0.888
# Germany     80.9400   3874437        357114                    0.916
# Italy       60.6550   2167744        301336                    0.873
# Japan      127.0671   4602367        377930                    0.891
# UK          64.5110   2950039        242495                    0.907
# USA        318.5230  17348075       9525067                    0.915
#
#         Continent Language
# Canada    America  English
# France     Europe  English
# Germany    Europe  English
# Italy      Europe  English
# Japan        Asia  English
# UK         Europe  English
# USA       America  English

# %%
df.rename(index = str.upper)
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# CANADA             35.4670   1785387       9984670  0.913   America  English
# FRANCE             63.9510   2833687        640679  0.888    Europe  English
# GERMANY            80.9400   3874437        357114  0.916    Europe  English
# ITALY              60.6550   2167744        301336  0.873    Europe  English
# JAPAN             127.0671   4602367        377930  0.891      Asia  English
# UNITED KINGDOM     64.5110   2950039        242495  0.907    Europe  English
# UNITED STATES     318.5230  17348075       9525067  0.915   America  English

# %% [markdown]
# Creating Columns from combination of columns

# %%
### Create GDP Per capita
df['GDP_PER_CAPITA'] = df['GDP']/df['Population']

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language  \
# Canada             35.4670   1785387       9984670  0.913   America  English
# France             63.9510   2833687        640679  0.888    Europe  English
# Germany            80.9400   3874437        357114  0.916    Europe  English
# Italy              60.6550   2167744        301336  0.873    Europe  English
# Japan             127.0671   4602367        377930  0.891      Asia  English
# United Kingdom     64.5110   2950039        242495  0.907    Europe  English
# United States     318.5230  17348075       9525067  0.915   America  English
#
#                 GDP_PER_CAPITA
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35738.916825
# Japan             36219.973542
# United Kingdom    45729.239975
# United States     54464.120330

# %% [markdown]
# Statistical info

# %%
df.head()
# Out:
#          Population      GDP  Surface Area    HDI Continent Language  \
# Canada      35.4670  1785387       9984670  0.913   America  English
# France      63.9510  2833687        640679  0.888    Europe  English
# Germany     80.9400  3874437        357114  0.916    Europe  English
# Italy       60.6550  2167744        301336  0.873    Europe  English
# Japan      127.0671  4602367        377930  0.891      Asia  English
#
#          GDP_PER_CAPITA
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35738.916825
# Japan      36219.973542

# %%
population = df['Population']
population.mean()
# Out:
# 107.3020142857143

# %%
population.std()
# Out:
# 97.25097581259239

# %%
population.median()
# Out:
# 64.511

# %%
population.quantile(.25)
# Out:
# 62.303
